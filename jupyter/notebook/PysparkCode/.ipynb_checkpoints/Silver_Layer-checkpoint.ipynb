# %% [markdown]
# #Silver Layer - This layer is for Data Munging, Enrichment, customization and curation.  We can store the data as per the Business needs

# %%
#Run the below notebook for invoking the function to this notebook
# %run "/notebook/PysparkCode/Generic_function.ipynb"

# %%
#Applying Strict Schema to the DataFrame, so creating schema
from pyspark.sql.types import *

schema_under = StructType([
        StructField("Job_ID", IntegerType(), True),
        StructField("Agency", StringType(), True),
        StructField("Posting_Type", StringType(), True),
        StructField("No_Of_Positions", IntegerType(), True),
        StructField("Business_Title", StringType(), True),
        StructField("Civil_Service_Title", StringType(), True),
        StructField("Title_Code_No", StringType(), True),
        StructField("Level", StringType(), True),
        StructField("Job_Category", StringType(), True),
        StructField("Full-Time/Part-Time_indicator", StringType(), True),
        StructField("Salary_Range_From", DoubleType(), True),
        StructField("Salary_Range_To", DoubleType(), True),
        StructField("Salary_Frequency", StringType(), True),
        StructField("Work_Location", StringType(), True),
        StructField("Division/Work_Unit", StringType(), True),
        StructField("Job_Description", StringType(), True),
        StructField("Minimum_Qual_Requirements", StringType(), True),
        StructField("Preferred_Skills", StringType(), True),
        StructField("Additional_Information", StringType(), True),
        StructField("To_Apply", StringType(), True),
        StructField("Hours/Shift", StringType(), True),
        StructField("Work_Location_1", StringType(), True),
        StructField("Recruitment_Contact", StringType(), True),
        StructField("Residency_Requirement", StringType(), True),
        StructField("Posting_Date", StringType(), True),
        StructField("Post_Until", StringType(), True),
        StructField("Posting_Updated", StringType(), True),
        StructField("Process_Date", StringType(), True),
        StructField("Corrupt_rows", StringType(), True)
    ])

#Applying Strict Schema to the DataFrame, so creating schema

from pyspark.sql.types import *

Struct_schema = StructType([
        StructField("Job ID", IntegerType(), True),
        StructField("Agency", StringType(), True),
        StructField("Posting Type", StringType(), True),
        StructField("# Of Positions", IntegerType(), True),
        StructField("Business Title", StringType(), True),
        StructField("Civil Service Title", StringType(), True),
        StructField("Title Code No", StringType(), True),
        StructField("Level", StringType(), True),
        StructField("Job Category", StringType(), True),
        StructField("Full-Time/Part-Time indicator", StringType(), True),
        StructField("Salary Range From", DoubleType(), True),
        StructField("Salary Range To", DoubleType(), True),
        StructField("Salary Frequency", StringType(), True),
        StructField("Work Location", StringType(), True),
        StructField("Division/Work Unit", StringType(), True),
        StructField("Job Description", StringType(), True),
        StructField("Minimum Qual Requirements", StringType(), True),
        StructField("Preferred Skills", StringType(), True),
        StructField("Additional Information", StringType(), True),
        StructField("To Apply", StringType(), True),
        StructField("Hours/Shift", StringType(), True),
        StructField("Work Location 1", StringType(), True),
        StructField("Recruitment Contact", StringType(), True),
        StructField("Residency Requirement", StringType(), True),
        StructField("Posting Date", StringType(), True),
        StructField("Post Until", StringType(), True),
        StructField("Posting Updated", StringType(), True),
        StructField("Process Date", StringType(), True),
        StructField("Corrupt_rows", StringType(), True)
    ])

# %% [markdown]
# ##Data Munging

# %%
#Reads the file in orc format and do count level validation
df=Active_Munging("/dataset/Bronze",Struct_schema,"Corrupt_rows","Job ID")
print("Total Number of records",df.count())
print("Total Number of De-Duplicated records",df.distinct().count())
#df.show()
# Out:
# Total Number of records 2946
# Total Number of De-Duplicated records 2915

# %% [markdown]
# ##Data Enrichment - Pre processing the data

# %%
#df.show()
silver_df=data_enrichment(df,["Posting Date","Post Until","Posting Updated","Process Date"],"Job ID")
silver_df.show(12)
# Out:
# +------+--------------------+------------+--------------+--------------------+--------------------+-------------+-----+--------------------+-----------------------------+-----------------+---------------+----------------+--------------------+--------------------+--------------------+-------------------------+--------------------+----------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+-------------------+------------+
# |Job ID|              Agency|Posting Type|# Of Positions|      Business Title| Civil Service Title|Title Code No|Level|        Job Category|Full-Time/Part-Time indicator|Salary Range From|Salary Range To|Salary Frequency|       Work Location|  Division/Work Unit|     Job Description|Minimum Qual Requirements|    Preferred Skills|Additional Information|            To Apply|         Hours/Shift|     Work Location 1| Recruitment Contact|Residency Requirement|        Posting Date|          Post Until|     Posting Updated|       Process Date|Corrupt_rows|
# +------+--------------------+------------+--------------+--------------------+--------------------+-------------+-----+--------------------+-----------------------------+-----------------+---------------+----------------+--------------------+--------------------+--------------------+-------------------------+--------------------+----------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+-------------------+------------+
# |406148|DEPT OF HEALTH/ME...|    Internal|             1|Assistant General...|     AGENCY ATTORNEY|        30087|    1|Health Legal Affairs|                            F|          61237.0|       75981.24|          Annual|   42-09 28th Street|       Legal Affairs|The Contracts Uni...|     "1. Admission to ...| candidates must ...|   in the areas of ...| in the areas of ...|Knowledge of Proc...|"**Incumbents mus...|Apply online with...|                  N/A|                 N/A|                 N/A|New York City res...|2019-10-28 00:00:00|         N/A|
# |406661|DEPT OF HEALTH/ME...|    External|             1|Supervising Socia...|SUPERVISOR III SO...|        52633|    0|              Health|                            F|          70900.0|        90720.0|          Annual|161-169 East 110 ...|CHECW-HRLM NEIGHB...|The Center for He...|     1. A Master's Deg...|Bilingual Spanish...|  **IMPORTANT NOTES...|Apply online with...|                 N/A|                 N/A|                 N/A| New York City res...|2019-09-24T00:00:...|2019-12-23T00:00:...|2019-09-24T00:00:...|2019-12-17 00:00:00|         N/A|
# |407734|DEPT OF ENVIRONME...|    External|             1|Stationary Engine...|STATIONARY ENGINE...|        91645|    0|Building Operatio...|                            F|            62.74|          62.74|          Hourly|1270 Victory Blvd...|New Clove Pump St...|The NYC Departmen...|     "1. Five years of...| accredited by re...|              national| professional or ...| with a major in ...| Wastewater Treat...| Environmental He...|  Environmental Co...| Electrical Techn...| Mechanical Techn...| and four years o...|               null|         N/A|
# |415351|DEPT OF INFO TECH...|    Internal|             1|Senior Director, ...|COMPUTER SYSTEMS ...|        10050|   M3|Technology, Data ...|                            F|          69940.0|       165000.0|          Annual|        2 Metro Tech|Information Security|DoITT provides fo...|     "1. A master's de...| ""2"" or ""3"" a...|   all candidates m...| including the 18...|          managerial| executive or sup...|              design|  implementation o...|The preferred can...|                 N/A|Candidates Must H...|               null|         N/A|
# |395945|NYC HOUSING AUTHO...|    External|             5|Fire Safety Overs...|ASSOCIATE FIRE PR...|        31662|    1|Public Safety, In...|                            F|          52063.0|        73309.0|          Annual|Environmental Hea...|Environmental Hea...|The New York City...|     "1. Five (5) year...|           chemistry|   physics or engin...| up to a maximum ...|1.	Five (5) years...|NYCHA employees a...|"Click the ""Appl...|                  N/A|                 N/A|                 N/A|NYCHA has no resi...|2019-05-24 00:00:00|         N/A|
# |399565|DEPT OF INFO TECH...|    External|             1|Senior Director, ...|IT SECURITY SPECI...|         6798|    0|Technology, Data ...|                          N/A|          75000.0|       180000.0|          Annual|255 Greenwich Street|Citywide Cybersec...|About New York Ci...|     "1. A baccalaurea...|The preferred can...|                   N/A|* Interested appl...|Day - Due to the ...|        New York, NY|                 N/A| City Residency is...|2019-09-30T00:00:...|                 N/A|2019-10-02T00:00:...|2019-12-17 00:00:00|         N/A|
# |243640|ADMIN FOR CHILDRE...|    External|             2|Juvenile Justice ...|ADMINISTRATIVE DI...|        10016|   M1|     Social Services|                            F|          53051.0|       145991.0|          Annual|492 First Avenue,...|Satterwhite Acade...|Reporting to the ...|     "1. A master's de...| all candidates m...|  The preferred can...|Section 424-A of ...|"Click on the ""A...|                 N/A|                 N/A|                  N/A|New York City res...|2016-07-08T00:00:...|                 N/A|2018-01-09 00:00:00|         N/A|
# |375114|DEPT OF HEALTH/ME...|    Internal|             2|Communications Sp...|CUSTOMER INFORMAT...|        60888|    1|Communications & ...|                            F|          39170.0|        39170.0|          Annual|421 East 26th Str...|     OCME-Operations|THIS POSITION IS ...|     "1. A baccalaurea...| full-time experi...|   databases and in...| help desk or pub...| help desk or pub...| all candidates m...| candidates must ...|  in addition to m...| one more year of...| candidates must ...| in addition to m...|               null|         N/A|
# |376088|DEPT OF ENVIRONME...|    Internal|             2|.Net Programmer /...|COMPUTER ASSOC (S...|        13631|    1|Technology, Data ...|                            F|          64657.0|        89634.0|          Annual|59-17 Junction Bl...|         ACCO Office|Only those applic...|     "1. A baccalaurea...| 24 semester cred...|   or a certificate...| may be substitut...| all candidates m...|â€¢	The ideal can...|DEP is an equal o...| "Click on the ""A...|            35 hours|59-17 Junction Bl...|                 N/A|               null|         N/A|
# |376882|DEPT OF ENVIRONME...|    Internal|            80|Seasonal City Par...|    CITY PARK WORKER|        90641|    0|Building Operatio...|                            F|          16.1418|        25.0733|          Hourly|329 Greenpoint Av...| WSO-OGI Maintenance|The NYC Departmen...|     Qualification Req...|Experience with h...|  Appointments are ...|"To Apply, click ...|                 N/A|                 N/A|                 N/A| New York City res...|2018-12-20T00:00:...|                 N/A|2019-01-17T00:00:...|2019-12-17 00:00:00|         N/A|
# |425067|DEPT OF PARKS & R...|    Internal|             2|Deputy Chief of R...|ADMINISTRATIVE ST...|        1002D|    0|Administration & ...|                            F|         100000.0|       100000.0|          Annual|      105 St & 5 Ave|  Central Recreation|Major Responsibil...|     "1. A master's de...| including the 18...|            managerial| administrative o...| as described in ...|1.	Excellent mana...|ONLY CURRENT PERM...| Year-Round Parks ...|                 N/A|                 TBD|                 N/A|               null|         N/A|
# |268905|ADMIN FOR CHILDRE...|    Internal|             4|Supervisor/Audito...|DIRECTOR OF FIELD...|        95600|   M1|     Social Services|                            F|          54643.0|        94478.0|          Annual|150 William Stree...|Quality Improveme...|The Supervisor/Au...|     "1. A baccalaurea...| all candidates m...|        administrative|          managerial| or executive cap...|The preferred can...|Section 424-A of ...| "Click on the ""A...|                 N/A|                 N/A|                 N/A|               null|         N/A|
# +------+--------------------+------------+--------------+--------------------+--------------------+-------------+-----+--------------------+-----------------------------+-----------------+---------------+----------------+--------------------+--------------------+--------------------+-------------------------+--------------------+----------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+-------------------+------------+
# only showing top 12 rows

# %% [markdown]
# ##Data Curation - transformation, filtering<br>
# List of KPIs to be resolved:<br>
# Whats the number of jobs posting per category (Top 10)?<br>
# Whats the salary distribution per job category?<br>
# Is there any correlation between the higher degree and the salary?<br>
# Whats the job posting having the highest salary per agency?<br>
# Whats the job positings average salary per agency for the last 2 years?<br>
# What are the highest paid skills in the US market?<br>

# %%
#Whats the number of jobs posting per category (Top 10)?
def No_of_jobs(df):
    df1=df.groupBy(upper(col("Job Category")).alias("Job Category")).count().orderBy("Count",ascending=False).limit(10)
    return df

No_of_jobs(silver_df).show()
# Out:
# +------+--------------------+------------+--------------+--------------------+--------------------+-------------+-----+--------------------+-----------------------------+-----------------+---------------+----------------+--------------------+--------------------+--------------------+-------------------------+--------------------+----------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+-------------------+------------+
# |Job ID|              Agency|Posting Type|# Of Positions|      Business Title| Civil Service Title|Title Code No|Level|        Job Category|Full-Time/Part-Time indicator|Salary Range From|Salary Range To|Salary Frequency|       Work Location|  Division/Work Unit|     Job Description|Minimum Qual Requirements|    Preferred Skills|Additional Information|            To Apply|         Hours/Shift|     Work Location 1| Recruitment Contact|Residency Requirement|        Posting Date|          Post Until|     Posting Updated|       Process Date|Corrupt_rows|
# +------+--------------------+------------+--------------+--------------------+--------------------+-------------+-----+--------------------+-----------------------------+-----------------+---------------+----------------+--------------------+--------------------+--------------------+-------------------------+--------------------+----------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+-------------------+------------+
# |406148|DEPT OF HEALTH/ME...|    Internal|             1|Assistant General...|     AGENCY ATTORNEY|        30087|    1|Health Legal Affairs|                            F|          61237.0|       75981.24|          Annual|   42-09 28th Street|       Legal Affairs|The Contracts Uni...|     "1. Admission to ...| candidates must ...|   in the areas of ...| in the areas of ...|Knowledge of Proc...|"**Incumbents mus...|Apply online with...|                  N/A|                 N/A|                 N/A|New York City res...|2019-10-28 00:00:00|         N/A|
# |406661|DEPT OF HEALTH/ME...|    External|             1|Supervising Socia...|SUPERVISOR III SO...|        52633|    0|              Health|                            F|          70900.0|        90720.0|          Annual|161-169 East 110 ...|CHECW-HRLM NEIGHB...|The Center for He...|     1. A Master's Deg...|Bilingual Spanish...|  **IMPORTANT NOTES...|Apply online with...|                 N/A|                 N/A|                 N/A| New York City res...|2019-09-24T00:00:...|2019-12-23T00:00:...|2019-09-24T00:00:...|2019-12-17 00:00:00|         N/A|
# |407734|DEPT OF ENVIRONME...|    External|             1|Stationary Engine...|STATIONARY ENGINE...|        91645|    0|Building Operatio...|                            F|            62.74|          62.74|          Hourly|1270 Victory Blvd...|New Clove Pump St...|The NYC Departmen...|     "1. Five years of...| accredited by re...|              national| professional or ...| with a major in ...| Wastewater Treat...| Environmental He...|  Environmental Co...| Electrical Techn...| Mechanical Techn...| and four years o...|               null|         N/A|
# |415351|DEPT OF INFO TECH...|    Internal|             1|Senior Director, ...|COMPUTER SYSTEMS ...|        10050|   M3|Technology, Data ...|                            F|          69940.0|       165000.0|          Annual|        2 Metro Tech|Information Security|DoITT provides fo...|     "1. A master's de...| ""2"" or ""3"" a...|   all candidates m...| including the 18...|          managerial| executive or sup...|              design|  implementation o...|The preferred can...|                 N/A|Candidates Must H...|               null|         N/A|
# |395945|NYC HOUSING AUTHO...|    External|             5|Fire Safety Overs...|ASSOCIATE FIRE PR...|        31662|    1|Public Safety, In...|                            F|          52063.0|        73309.0|          Annual|Environmental Hea...|Environmental Hea...|The New York City...|     "1. Five (5) year...|           chemistry|   physics or engin...| up to a maximum ...|1.	Five (5) years...|NYCHA employees a...|"Click the ""Appl...|                  N/A|                 N/A|                 N/A|NYCHA has no resi...|2019-05-24 00:00:00|         N/A|
# |399565|DEPT OF INFO TECH...|    External|             1|Senior Director, ...|IT SECURITY SPECI...|         6798|    0|Technology, Data ...|                          N/A|          75000.0|       180000.0|          Annual|255 Greenwich Street|Citywide Cybersec...|About New York Ci...|     "1. A baccalaurea...|The preferred can...|                   N/A|* Interested appl...|Day - Due to the ...|        New York, NY|                 N/A| City Residency is...|2019-09-30T00:00:...|                 N/A|2019-10-02T00:00:...|2019-12-17 00:00:00|         N/A|
# |243640|ADMIN FOR CHILDRE...|    External|             2|Juvenile Justice ...|ADMINISTRATIVE DI...|        10016|   M1|     Social Services|                            F|          53051.0|       145991.0|          Annual|492 First Avenue,...|Satterwhite Acade...|Reporting to the ...|     "1. A master's de...| all candidates m...|  The preferred can...|Section 424-A of ...|"Click on the ""A...|                 N/A|                 N/A|                  N/A|New York City res...|2016-07-08T00:00:...|                 N/A|2018-01-09 00:00:00|         N/A|
# |375114|DEPT OF HEALTH/ME...|    Internal|             2|Communications Sp...|CUSTOMER INFORMAT...|        60888|    1|Communications & ...|                            F|          39170.0|        39170.0|          Annual|421 East 26th Str...|     OCME-Operations|THIS POSITION IS ...|     "1. A baccalaurea...| full-time experi...|   databases and in...| help desk or pub...| help desk or pub...| all candidates m...| candidates must ...|  in addition to m...| one more year of...| candidates must ...| in addition to m...|               null|         N/A|
# |376088|DEPT OF ENVIRONME...|    Internal|             2|.Net Programmer /...|COMPUTER ASSOC (S...|        13631|    1|Technology, Data ...|                            F|          64657.0|        89634.0|          Annual|59-17 Junction Bl...|         ACCO Office|Only those applic...|     "1. A baccalaurea...| 24 semester cred...|   or a certificate...| may be substitut...| all candidates m...|â€¢	The ideal can...|DEP is an equal o...| "Click on the ""A...|            35 hours|59-17 Junction Bl...|                 N/A|               null|         N/A|
# |376882|DEPT OF ENVIRONME...|    Internal|            80|Seasonal City Par...|    CITY PARK WORKER|        90641|    0|Building Operatio...|                            F|          16.1418|        25.0733|          Hourly|329 Greenpoint Av...| WSO-OGI Maintenance|The NYC Departmen...|     Qualification Req...|Experience with h...|  Appointments are ...|"To Apply, click ...|                 N/A|                 N/A|                 N/A| New York City res...|2018-12-20T00:00:...|                 N/A|2019-01-17T00:00:...|2019-12-17 00:00:00|         N/A|
# |425067|DEPT OF PARKS & R...|    Internal|             2|Deputy Chief of R...|ADMINISTRATIVE ST...|        1002D|    0|Administration & ...|                            F|         100000.0|       100000.0|          Annual|      105 St & 5 Ave|  Central Recreation|Major Responsibil...|     "1. A master's de...| including the 18...|            managerial| administrative o...| as described in ...|1.	Excellent mana...|ONLY CURRENT PERM...| Year-Round Parks ...|                 N/A|                 TBD|                 N/A|               null|         N/A|
# |268905|ADMIN FOR CHILDRE...|    Internal|             4|Supervisor/Audito...|DIRECTOR OF FIELD...|        95600|   M1|     Social Services|                            F|          54643.0|        94478.0|          Annual|150 William Stree...|Quality Improveme...|The Supervisor/Au...|     "1. A baccalaurea...| all candidates m...|        administrative|          managerial| or executive cap...|The preferred can...|Section 424-A of ...| "Click on the ""A...|                 N/A|                 N/A|                 N/A|               null|         N/A|
# |352367|DEPT OF HEALTH/ME...|    Internal|             2|Budget Analyst, B...|           ECONOMIST|        40910|    1|Finance, Accounti...|                            F|          42288.0|        59400.0|          Annual|125 Worth Street,...|Budget Administra...|The New York City...|     "1. A master's de...| in addition to m...|   at least one add...| in addition to m...| at least two add...|We seek candidate...|**IMPORTANT NOTES...| Apply online with...|                 N/A|                 N/A|                 N/A|               null|         N/A|
# |380956|HOUSING PRESERVAT...|    External|             1|NYC 15/15 Project...|HOUSING DEVELOPME...|        22507|    2|Constituent Servi...|                            F|          65783.0|        75651.0|          Annual|     100 Gold Street|      NYC 15 Program|The Division of T...|     "1. A baccalaurea...|â€¢	Excellent com...|                   N/A|       Apply On-line|                 N/A|     100 Gold Street|                 N/A| New York City res...|2019-01-17T00:00:...|                 N/A|2019-01-24T00:00:...|2019-12-17 00:00:00|         N/A|
# |422479|DEPARTMENT OF CIT...|    Internal|             1|    EARD TEAM LEADER|        CITY PLANNER|        22122|    3|Engineering, Arch...|                            F|          73294.0|        85000.0|          Annual|120 Broadway, New...|Environmental Ass...|THE AGENCY  The D...|     "1. A baccalaurea...|      urban planning|          urban design|        architecture| landscape archit...| transportation e...| public administr...|  economic develop...| all candidates m...| individuals must...| after meeting th...|               null|         N/A|
# |423960|HOUSING PRESERVAT...|    Internal|             1|Director of Marke...|ASSOCIATE HOUSING...|        22508|    0|Constituent Servi...|                            F|          74650.0|       105000.0|          Annual|     100 Gold Street|APM - Policy and ...|HPDâ€™s Division ...|     "1.A baccalaureat...|       city planning|   business or publ...|             finance|        architecture| engineering or o...| all candidates m...| â€¢	Experience ma...|                 N/A|        Apply Online|                 N/A|               null|         N/A|
# |423999|DEPARTMENT OF BUS...|    Internal|             1|      .NET DEVELOPER|CERT IT DEVELOPER...|        13643|    3|Technology, Data ...|                            F|          92194.0|       110000.0|          Annual| 110 William St. N Y|          Technology|SBS is seeking a ...|     Professional/Vend...|Â¿7+ years of str...|                   N/A|PLEASE NOTE: OPEN...|                 N/A|                 N/A|                 N/A| New York City Res...|2019-12-11T00:00:...|                 N/A|2019-12-16T00:00:...|2019-12-17 00:00:00|         N/A|
# |424200|DEPARTMENT OF TRA...|    Internal|             1|Assistant Civil E...|ASSISTANT CIVIL E...|        20210|    0|Engineering, Arch...|                            F|          57078.0|        85646.0|          Annual|28-11 Queens Plaz...|Design & Construc...|Design & Construc...|     1.  A baccalaurea...|New York State dr...|  This position is ...|All resumes are t...|35 Hours/ To Be D...|28-11 Queens Plaz...|                 N/A| New York City Res...|2019-12-08T00:00:...|2020-01-31T00:00:...|2019-12-13T00:00:...|2019-12-17 00:00:00|         N/A|
# |424250|TAXI & LIMOUSINE ...|    External|             1|IT Technical Support|COMPUTER ASSOC (T...|        13611|    1|Technology, Data ...|                            F|          26.1615|           32.5|          Hourly|33 Beaver St, New...|Management Inform...|MUST BE CURRENTLY...|     "Qualification Re...| acquired with th...|   as described in ...|               ""2""| or ""3"" above. ...| from an accredit...| for six months o...|  all candidates m...|  mid-range computer| and/or LAN or WA...| acquired within ...|               null|         N/A|
# |424879|HOUSING PRESERVAT...|    External|             1|        MEP Reviewer| MECHANICAL ENGINEER|        20415|    1|Engineering, Arch...|                            F|          67757.0|        88000.0|          Annual|     100 Gold Street|Eng, Design Const...|Your Team:   The ...|     "(1) Four (4) yea...| to be eligible f...|   individuals must...|Preferred skills ...|                 N/A|       Apply Online.|                 N/A|      100 Gold Street|                 N/A|New York City Res...|2019-12-04T00:00:...|2020-01-03 00:00:00|         N/A|
# +------+--------------------+------------+--------------+--------------------+--------------------+-------------+-----+--------------------+-----------------------------+-----------------+---------------+----------------+--------------------+--------------------+--------------------+-------------------------+--------------------+----------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+-------------------+------------+
# only showing top 20 rows

# %%
#Whats the salary distribution per job category?
def Salary_distribution(df):
    SF_LIST=df.select(upper(col("Job Category")).alias("Job Category"),upper(col("Salary Frequency")).alias("Salary Frequency")).distinct()
    return SF_LIST

Salary_distribution(silver_df).show(truncate=False)
# Out:
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+
# |Job Category                                                                                                                                                                                             |Salary Frequency|
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+
# |CONSTITUENT SERVICES & COMMUNITY PROGRAMS BUILDING OPERATIONS & MAINTENANCE                                                                                                                              |ANNUAL          |
# |CONSTITUENT SERVICES & COMMUNITY PROGRAMS POLICY, RESEARCH & ANALYSIS PUBLIC SAFETY, INSPECTIONS, & ENFORCEMENT                                                                                          |ANNUAL          |
# |TECHNOLOGY, DATA & INNOVATION POLICY, RESEARCH & ANALYSIS                                                                                                                                                |ANNUAL          |
# |COMMUNICATIONS & INTERGOVERNMENTAL AFFAIRS                                                                                                                                                               |ANNUAL          |
# |CLERICAL & ADMINISTRATIVE SUPPORT                                                                                                                                                                        |ANNUAL          |
# |HEALTH SOCIAL SERVICES                                                                                                                                                                                   |ANNUAL          |
# |COMMUNITY & BUSINESS SERVICES SOCIAL SERVICES                                                                                                                                                            |ANNUAL          |
# |CONSTITUENT SERVICES & COMMUNITY PROGRAMS TECHNOLOGY, DATA & INNOVATION PUBLIC SAFETY, INSPECTIONS, & ENFORCEMENT SOCIAL SERVICES                                                                        |HOURLY          |
# |LEGAL AFFAIRS                                                                                                                                                                                            |ANNUAL          |
# |CLERICAL & ADMINISTRATIVE SUPPORT LEGAL                                                                                                                                                                  |ANNUAL          |
# |POLICY, RESEARCH & ANALYSIS PUBLIC SAFETY, INSPECTIONS, & ENFORCEMENT SOCIAL SERVICES                                                                                                                    |ANNUAL          |
# |CLERICAL & ADMINISTRATIVE SUPPORT POLICY & ANALYSIS                                                                                                                                                      |ANNUAL          |
# |ADMINISTRATION & HUMAN RESOURCES FINANCE, ACCOUNTING, & PROCUREMENT TECHNOLOGY, DATA & INNOVATION BUILDING OPERATIONS & MAINTENANCE POLICY, RESEARCH & ANALYSIS PUBLIC SAFETY, INSPECTIONS, & ENFORCEMENT|ANNUAL          |
# |ADMINISTRATION & HUMAN RESOURCES POLICY, RESEARCH & ANALYSIS PUBLIC SAFETY, INSPECTIONS, & ENFORCEMENT                                                                                                   |ANNUAL          |
# |CONSTITUENT SERVICES & COMMUNITY PROGRAMS POLICY, RESEARCH & ANALYSIS SOCIAL SERVICES                                                                                                                    |ANNUAL          |
# |ADMINISTRATION & HUMAN RESOURCES CONSTITUENT SERVICES & COMMUNITY PROGRAMS FINANCE, ACCOUNTING, & PROCUREMENT SOCIAL SERVICES                                                                            |ANNUAL          |
# |ADMINISTRATION & HUMAN RESOURCES BUILDING OPERATIONS & MAINTENANCE                                                                                                                                       |ANNUAL          |
# |POLICY, RESEARCH & ANALYSIS SOCIAL SERVICES                                                                                                                                                              |ANNUAL          |
# |CONSTITUENT SERVICES & COMMUNITY PROGRAMS FINANCE, ACCOUNTING, & PROCUREMENT POLICY, RESEARCH & ANALYSIS SOCIAL SERVICES                                                                                 |HOURLY          |
# |ADMINISTRATION & HUMAN RESOURCES CONSTITUENT SERVICES & COMMUNITY PROGRAMS COMMUNICATIONS & INTERGOVERNMENTAL AFFAIRS FINANCE, ACCOUNTING, & PROCUREMENT LEGAL AFFAIRS POLICY, RESEARCH & ANALYSIS       |HOURLY          |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+
# only showing top 20 rows

# %% [markdown]
# ##Data Customization

# %%
#Is there any correlation between the higher degree and the salary?
from pyspark.sql.functions import *
from pyspark.sql.types import *
import re

# Define UDF to extract education level from text
def extract_education_level(qual):
    if qual is None:
        return 0
    
    text = qual.lower()
    
# Define education level patterns
    if any(term in text for term in ['phd', 'doctorate', 'doctoral']):
        return 4
    elif any(term in text for term in ['master', 'mba', 'ma degree', 'ms degree', 'graduate degree']):
        return 3
    elif any(term in text for term in ['bachelor', 'baccalaureate', 'ba degree', 'bs degree', 'undergraduate']):
        return 2
    elif any(term in text for term in ['high school', 'diploma', 'ged', 'h.s.']):
        return 1
    else:
        return 0
    
# Calculate Average Salary and annual_salary

df_with_AvgSal = silver_df.withColumn("Average_Salary",((col("Salary Range From") + col("Salary Range To")) / 2)) \
                   .withColumn("Annual_salary",when(col("Salary Frequency") == "Annual", col("Average_Salary"))\
                                 .when(col("Salary Frequency") == "Hourly", col("Average_Salary") * 2080)\
                                 .when(col("Salary Frequency") == "Daily", col("Average_Salary") * 260)\
                                 .otherwise(None))


# Register UDF
extract_education_udf = udf(extract_education_level)



#write to table

df_with_AvgSal.write.orc("/dataset/Silver",mode="overwrite")

df_Enhanced=df_with_AvgSal.withColumn("Education_Level",extract_education_udf(col("Minimum Qual Requirements")))

#df_Enhanced.select("Education_Level","Annual_salary").show()
correlation = df_Enhanced.select(corr("Education_Level","Annual_salary"))
correlation.show()
#df_Enhanced.summary().show()
# Out:
# +------------------------------------+
# |corr(Education_Level, Annual_salary)|
# +------------------------------------+
# |                 0.13371207969841065|
# +------------------------------------+
